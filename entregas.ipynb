# %% [markdown]
# # PI4: Ciência de dados aplicada a situações de mercado

# %%
from src import helpers, analysis, visualizations

# %%
conector = helpers.ConectorBD()

# %% [markdown]
# ## Análise exploratória

# %% [markdown]
# ## Qualidade de dados

# %% [markdown]
# Valida que os dados são confiáveis antes de qualquer análise, evitando que nulos ou duplicatas distorçam métricas financeiras e induzam decisões equivocadas.

# %%
analysis.verificar_qualidade_dados(conector)
# Out:
# <style type="text/css">
# #T_47481 caption {
#   font-size: 14px;
#   font-weight: bold;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_47481 thead th {
#   background-color: #f0f0f0;
#   font-weight: bold;
#   text-align: center;
# }
# #T_47481 tbody tr:nth-child(even) {
#   background-color: #fafafa;
# }
# </style>
# <table id="T_47481">
#   <caption>Relatório de Qualidade dos Dados</caption>
#   <thead>
#     <tr>
#       <th id="T_47481_level0_col0" class="col_heading level0 col0" >Tabela</th>
#       <th id="T_47481_level0_col1" class="col_heading level0 col1" >Coluna</th>
#       <th id="T_47481_level0_col2" class="col_heading level0 col2" >Total registros</th>
#       <th id="T_47481_level0_col3" class="col_heading level0 col3" >Nulos</th>
#       <th id="T_47481_level0_col4" class="col_heading level0 col4" >Nulos (%)</th>
#       <th id="T_47481_level0_col5" class="col_heading level0 col5" >Duplicatas</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_47481_row0_col0" class="data row0 col0" >Vendas</td>
#       <td id="T_47481_row0_col1" class="data row0 col1" >order_id</td>
#       <td id="T_47481_row0_col2" class="data row0 col2" >1,000,000</td>
#       <td id="T_47481_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_47481_row0_col4" class="data row0 col4" >0.00%</td>
#       <td id="T_47481_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#     <tr>
#       <td id="T_47481_row1_col0" class="data row1 col0" >Vendas</td>
#       <td id="T_47481_row1_col1" class="data row1 col1" >order_date</td>
#       <td id="T_47481_row1_col2" class="data row1 col2" >1,000,000</td>
#       <td id="T_47481_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_47481_row1_col4" class="data row1 col4" >0.00%</td>
#       <td id="T_47481_row1_col5" class="data row1 col5" >0</td>
#     </tr>
#     <tr>
#       <td id="T_47481_row2_col0" class="data row2 col0" >Vendas</td>
#       <td id="T_47481_row2_col1" class="data row2 col1" >product_id</td>
#       <td id="T_47481_row2_col2" class="data row2 col2" >1,000,000</td>
#       <td id="T_47481_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_47481_row2_col4" class="data row2 col4" >0.00%</td>
#       <td id="T_47481_row2_col5" class="data row2 col5" >0</td>
#     </tr>
#     <tr>
#       <td id="T_47481_row3_col0" class="data row3 col0" >Vendas</td>
#       <td id="T_47481_row3_col1" class="data row3 col1" >store_id</td>
#       <td id="T_47481_row3_col2" class="data row3 col2" >1,000,000</td>
#       <td id="T_47481_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_47481_row3_col4" class="data row3 col4" >0.00%</td>
#       <td id="T_47481_row3_col5" class="data row3 col5" >0</td>
#     </tr>
#     <tr>
#       <td id="T_47481_row4_col0" class="data row4 col0" >Vendas</td>
#       <td id="T_47481_row4_col1" class="data row4 col1" >customer_id</td>
#       <td id="T_47481_row4_col2" class="data row4 col2" >1,000,000</td>
#       <td id="T_47481_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_47481_row4_col4" class="data row4 col4" >0.00%</td>
#       <td id="T_47481_row4_col5" class="data row4 col5" >0</td>
#     </tr>
#     <tr>
#       <td id="T_47481_row5_col0" class="data row5 col0" >Vendas</td>
#       <td id="T_47481_row5_col1" class="data row5 col1" >quantity</td>
#       <td id="T_47481_row5_col2" class="data row5 col2" >1,000,000</td>
#       <td id="T_47481_row5_col3" class="data row5 col3" >0</td>
#       <td id="T_47481_row5_col4" class="data row5 col4" >0.00%</td>
#       <td id="T_47481_row5_col5" class="data row5 col5" >0</td>
#     </tr>
#     <tr>
#       <td id="T_47481_row6_col0" class="data row6 col0" >Vendas</td>
#       <td id="T_47481_row6_col1" class="data row6 col1" >unit_price</td>
#       <td id="T_47481_row6_col2" class="data row6 col2" >1,000,000</td>
#       <td id="T_47481_row6_col3" class="data row6 col3" >0</td>
#       <td id="T_47481_row6_col4" class="data row6 col4" >0.00%</td>
#       <td id="T_47481_row6_col5" class="data row6 col5" >0</td>
#     </tr>
#     <tr>
#       <td id="T_47481_row7_col0" class="data row7 col0" >Vendas</td>
#       <td id="T_47481_row7_col1" class="data row7 col1" >discount</td>
#       <td id="T_47481_row7_col2" class="data row7 col2" >1,000,000</td>
#       <td id="T_47481_row7_col3" class="data row7 col3" >0</td>
#       <td id="T_47481_row7_col4" class="data row7 col4" >0.00%</td>
#       <td id="T_47481_row7_col5" class="data row7 col5" >0</td>
#     </tr>
#     <tr>
#       <td id="T_47481_row8_col0" class="data row8 col0" >Vendas</td>
#       <td id="T_47481_row8_col1" class="data row8 col1" >revenue</td>
#       <td id="T_47481_row8_col2" class="data row8 col2" >1,000,000</td>
#       <td id="T_47481_row8_col3" class="data row8 col3" >0</td>
#       <td id="T_47481_row8_col4" class="data row8 col4" >0.00%</td>
#       <td id="T_47481_row8_col5" class="data row8 col5" >0</td>
#     </tr>
#     <tr>
#       <td id="T_47481_row9_col0" class="data row9 col0" >Vendas</td>
#       <td id="T_47481_row9_col1" class="data row9 col1" >cost</td>
#       <td id="T_47481_row9_col2" class="data row9 col2" >1,000,000</td>
#       <td id="T_47481_row9_col3" class="data row9 col3" >0</td>
#       <td id="T_47481_row9_col4" class="data row9 col4" >0.00%</td>
#       <td id="T_47481_row9_col5" class="data row9 col5" >0</td>
#     </tr>
#     <tr>
#       <td id="T_47481_row10_col0" class="data row10 col0" >Vendas</td>
#       <td id="T_47481_row10_col1" class="data row10 col1" >profit</td>
#       <td id="T_47481_row10_col2" class="data row10 col2" >1,000,000</td>
#       <td id="T_47481_row10_col3" class="data row10 col3" >0</td>
#       <td id="T_47481_row10_col4" class="data row10 col4" >0.00%</td>
#       <td id="T_47481_row10_col5" class="data row10 col5" >0</td>
#     </tr>
#     <tr>
#       <td id="T_47481_row11_col0" class="data row11 col0" >Clientes</td>
#       <td id="T_47481_row11_col1" class="data row11 col1" >customer_id</td>
#       <td id="T_47481_row11_col2" class="data row11 col2" >50,000</td>
#       <td id="T_47481_row11_col3" class="data row11 col3" >0</td>
#       <td id="T_47481_row11_col4" class="data row11 col4" >0.00%</td>
#       <td id="T_47481_row11_col5" class="data row11 col5" >0</td>
#     </tr>
#     <tr>
#       <td id="T_47481_row12_col0" class="data row12 col0" >Clientes</td>
#       <td id="T_47481_row12_col1" class="data row12 col1" >age</td>
#       <td id="T_47481_row12_col2" class="data row12 col2" >50,000</td>
#       <td id="T_47481_row12_col3" class="data row12 col3" >0</td>
#       <td id="T_47481_row12_col4" class="data row12 col4" >0.00%</td>
#       <td id="T_47481_row12_col5" class="data row12 col5" >0</td>
#     </tr>
#     <tr>
#       <td id="T_47481_row13_col0" class="data row13 col0" >Clientes</td>
#       <td id="T_47481_row13_col1" class="data row13 col1" >gender</td>
#       <td id="T_47481_row13_col2" class="data row13 col2" >50,000</td>
#       <td id="T_47481_row13_col3" class="data row13 col3" >0</td>
#       <td id="T_47481_row13_col4" class="data row13 col4" >0.00%</td>
#       <td id="T_47481_row13_col5" class="data row13 col5" >0</td>
#     </tr>
#     <tr>
#       <td id="T_47481_row14_col0" class="data row14 col0" >Clientes</td>
#       <td id="T_47481_row14_col1" class="data row14 col1" >loyalty_member</td>
#       <td id="T_47481_row14_col2" class="data row14 col2" >50,000</td>
#       <td id="T_47481_row14_col3" class="data row14 col3" >0</td>
#       <td id="T_47481_row14_col4" class="data row14 col4" >0.00%</td>
#       <td id="T_47481_row14_col5" class="data row14 col5" >0</td>
#     </tr>
#     <tr>
#       <td id="T_47481_row15_col0" class="data row15 col0" >Clientes</td>
#       <td id="T_47481_row15_col1" class="data row15 col1" >join_date</td>
#       <td id="T_47481_row15_col2" class="data row15 col2" >50,000</td>
#       <td id="T_47481_row15_col3" class="data row15 col3" >0</td>
#       <td id="T_47481_row15_col4" class="data row15 col4" >0.00%</td>
#       <td id="T_47481_row15_col5" class="data row15 col5" >0</td>
#     </tr>
#     <tr>
#       <td id="T_47481_row16_col0" class="data row16 col0" >Produtos</td>
#       <td id="T_47481_row16_col1" class="data row16 col1" >product_id</td>
#       <td id="T_47481

# %% [markdown]
# ## KPIs gerais

# %% [markdown]
# Painel executivo de alto nível com receita total, margem e política de desconto, servindo como ponto de partida para avaliar saúde financeira e definir metas.

# %%
analysis.calcular_kpis_gerais(conector)
# Out:
# Idade Média dos Clientes                   44.0 anos
# Idade Mediana dos Clientes                   44 anos
# Receita Total Geral                  $ 25,486,128.86
# Margem de Lucro Média                          40.0%
# Desconto Máximo Oferecido                        20%
# Quantidade de Vendas Sem Desconto            625.128
# Name: Métricas Gerais de Negócio, dtype: str

# %% [markdown]
# ## Desempenho mensal de vendas

# %% [markdown]
# Monitoria de receita e lucro com crescimento MoM; a queda recorrente em fevereiro nos dois anos é um sinal acionável para campanhas promocionais sazonais.

# %%
analysis.obter_desempenho_mensal_vendas(conector)
# Out:
#      ano  mes  receita_total  custo_total  lucro_total  itens_vendidos  \
# 0   2023    1     1095019.20    656788.03    438230.77        128486.0
# 1   2023    2      968948.95    581689.52    387259.34        114154.0
# 2   2023    3     1084656.09    650889.73    433765.09        127279.0
# 3   2023    4     1038425.32    622598.35    415827.16        122274.0
# 4   2023    5     1083418.79    649925.83    433491.77        127781.0
# 5   2023    6     1046045.02    627889.96    418154.90        123276.0
# 6   2023    7     1083223.13    650264.50    432958.32        127294.0
# 7   2023    8     1086689.94    651700.28    434989.24        127634.0
# 8   2023    9     1056935.75    634845.65    422089.21        123993.0
# 9   2023   10     1071879.65    643134.31    428744.79        126607.0
# 10  2023   11     1039418.12    623352.19    416065.63        122440.0
# 11  2023   12     1080446.31    648424.33    432020.66        126886.0
# 12  2024    1     1084751.00    651245.63    433505.26        127676.0
# 13  2024    2     1010042.22    606209.12    403832.70        119074.0
# 14  2024    3     1084560.82    650492.55    434068.29        127605.0
# 15  2024    4     1043453.14    625910.51    417541.94        122805.0
# 16  2024    5     1078643.18    647185.87    431456.80        126987.0
# 17  2024    6     1038214.24    622215.94    415998.20        122183.0
# 18  2024    7     1085923.34    651655.05    434268.21        127768.0
# 19  2024    8     1082353.60    649071.15    433282.13        127646.0
# 20  2024    9     1051414.03    630657.28    420756.85        123630.0
# 21  2024   10     1075082.20    644835.55    430246.18        126677.0
# 22  2024   11     1039335.10    623716.87    415617.27        122351.0
# 23  2024   12     1077249.72    646856.20    430393.92        127083.0
#
#     margem_lucro_pct  crescimento_receita_mom_pct
# 0              40.02                         0.00
# 1              39.97                       -11.51
# 2              39.99                        11.94
# 3              40.04                        -4.26
# 4              40.01                         4.33
# 5              39.97                        -3.45
# 6              39.97                         3.55
# 7              40.03                         0.32
# 8              39.94                        -2.74
# 9              40.00                         1.41
# 10             40.03                        -3.03
# 11             39.99                         3.95
# 12             39.96                         0.00
# 13             39.98                        -6.89
# 14             40.02                         7.38
# 15             40.02                        -3.79
# 16             40.00                         3.37
# 17             40.07                        -3.75
# 18             39.99                         4.60
# 19             40.03                        -0.33
# 20             40.02                        -2.86
# 21             40.02                         2.25
# 22             39.99                        -3.33
# 23             39.95                         3.65

# %% [markdown]
# ## Segmentação clientes, e preferências por gênero

# %% [markdown]
# Direciona campanhas e programas de fidelidade; verifica se o loyalty diferencia comportamento de compra e se gênero implica preferências distintas de produto.

# %%
analysis.analisar_segmentacao_clientes(conector)
# Out:
#   faixa_etaria loyalty_member  media_gasto  soma_gasto  contagem_clientes
# 0        18-29            Não   510.369086  2905020.84               5692
# 1        18-29            Sim   508.461670  2871791.51               5648
# 2        30-44            Não   509.000431  3555877.01               6986
# 3        30-44            Sim   507.890956  3595867.97               7080
# 4        45-59            Não   511.444882  3604663.53               7048
# 5        45-59            Sim   510.045333  3617241.50               7092
# 6          60+            Não   512.094199  2647527.01               5170
# 7          60+            Sim   508.731925  2688139.49               5284

# %%
categoria, teor_cacau = analysis.analisar_preferencias_por_genero(conector)

# %%
categoria
# Out:
#    gender category  receita_total  volume_total  pct_receita_no_genero
# 0  Female  Praline     3301650.83        388603                  26.40
# 1  Female    White     3012364.77        354500                  24.08
# 2  Female     Dark     2628363.36        308953                  21.01
# 3  Female  Truffle     1945439.43        229230                  15.55
# 4  Female     Milk     1619929.50        190652                  12.95
# 5    Male  Praline     3363990.49        395832                  26.42
# 6    Male    White     3057807.43        360467                  24.02
# 7    Male     Dark     2669759.91        314294                  20.97
# 8    Male  Truffle     1978903.81        232972                  15.54
# 9    Male     Milk     1660438.69        194967                  13.04

# %%
teor_cacau
# Out:
#    gender         intensidade_cacau  receita_total  volume_total  \
# 0  Female  Intensidade Baixa (≤60%)     5074293.16        596813
# 1  Female             Amargo (>70%)     4753961.94        559946
# 2  Female      Meio Amargo (61–70%)     2679492.79        315179
# 3    Male  Intensidade Baixa (≤60%)     5162735.72        607826
# 4    Male             Amargo (>70%)     4830214.77        568945
# 5    Male      Meio Amargo (61–70%)     2737949.84        321761
#
#    pct_receita_no_genero
# 0                  40.57
# 1                  38.01
# 2                  21.42
# 3                  40.55
# 4                  37.94
# 5                  21.51

# %% [markdown]
# ## Análise dos produtos por característica de cacau

# %% [markdown]
# Orienta decisões de mix: quais categorias e percentuais de cacau são mais rentáveis, o que priorizar em gôndola e o que pode ser descontinuado.

# %%
categoria, cacau = analysis.analisar_produtos_cacau(conector)

# %%
categoria
# Out:
#    category  cocoa_percent  volume_total  lucro_total
# 0      Dark             50        177723    604656.66
# 1      Dark             60         45028    153113.96
# 2      Dark             70        148133    504046.53
# 3      Dark             80        133125    452762.53
# 4      Dark             90        119238    406092.40
# 5      Milk             50        133849    456010.90
# 6      Milk             60         44359    150770.01
# 7      Milk             70         59593    202786.26
# 8      Milk             80         29821    102038.26
# 9      Milk             90        117997    400801.70
# 10  Praline             50        194147    658979.99
# 11  Praline             60        132568    450199.00
# 12  Praline             70        221229    752837.25
# 13  Praline             80        133315    453904.60
# 14  Praline             90        103176    349321.95
# 15  Truffle             50        119365    404554.23
# 16  Truffle             60        103711    353862.06
# 17  Truffle             70         29941    101433.03
# 18  Truffle             80        134296    455098.38
# 19  Truffle             90         74889    254254.84
# 20    White             50        134926    457812.56
# 21    White             60        118963    405105.51
# 22    White             70        178044    605014.39
# 23    White             80        118985    403884.98
# 24    White             90        164049    556299.93

# %%
cacau
# Out:
#           intensidade_cacau  lucro_total  volume_total
# 0             Amargo (>70%)   3834459.57       1128891
# 1  Intensidade Baixa (≤60%)   4095064.88       1204639
# 2      Meio Amargo (61-70%)   2166117.46        636940

# %% [markdown]
# ## Desempenho das lojas

# %% [markdown]
# Classifica unidades em tiers para priorizar recursos, identificar referências operacionais e sinalizar onde intervir.

# %%
analysis.analisar_desempenho_lojas(conector)
# Out:
#    store_id  unit_price          store_name       city    country store_type  \
# 0      S074        9.12  Chocolate Store 74     Sydney        USA     Online
# 1      S033        3.77  Chocolate Store 33    Toronto  Australia     Retail
# 2      S050        9.81  Chocolate Store 50   New York     Canada    Airport
# 3      S027        6.09  Chocolate Store 27     Sydney    Germany    Airport
# 4      S022        6.61  Chocolate Store 22     Berlin        USA     Retail
# ..      ...         ...                 ...        ...        ...        ...
# 95     S077        6.65  Chocolate Store 77      Paris         UK    Airport
# 96     S002       14.16   Chocolate Store 2  Melbourne     Canada       Mall
# 97     S048       10.74  Chocolate Store 48    Toronto     Canada    Airport
# 98     S057       12.46  Chocolate Store 57     London         UK    Airport
# 99     S004       13.06   Chocolate Store 4      Paris         UK    Airport
#
#     receita_total  custo_total  lucro_total  itens_vendidos  total_pedidos  \
# 0       261393.77    156584.46    104809.57           30761          10154
# 1       260672.37    156152.51    104519.64           30671          10186
# 2       259526.62    155526.42    104000.38           30490          10110
# 3       259006.23    155171.82    103834.60           30427          10163
# 4       258914.68    155215.59    103699.15           30288          10136
# ..            ...          ...          ...             ...            ...
# 95      250220.40    150289.63     99930.86           29399           9786
# 96      249737.67    149913.70     99823.70           29518           9875
# 97      249272.38    149794.28     99478.02           29364           9831
# 98      248778.57    149435.94     99342.69           29330           9794
# 99      247858.64    148558.68     99299.97           29301           9829
#
#     margem_lucro_pct  ticket_medio   tier_desempenho
# 0              40.10         25.74   Alto desempenho
# 1              40.10         25.59   Alto desempenho
# 2              40.07         25.67   Alto desempenho
# 3              40.09         25.49   Alto desempenho
# 4              40.05         25.54   Alto desempenho
# ..               ...           ...               ...
# 95             39.94         25.57  Baixo desempenho
# 96             39.97         25.29  Baixo desempenho
# 97             39.91         25.36  Baixo desempenho
# 98             39.93         25.40  Baixo desempenho
# 99             40.06         25.22  Baixo desempenho
#
# [100 rows x 14 columns]

# %% [markdown]
# ## Descontos

# %% [markdown]
# Quantifica o trade-off entre volume e margem por faixa de desconto, com correlação e impacto em pontos percentuais como evidência objetiva para revisar a política.

# %%
faixas, correlacao = analysis.analisar_impacto_desconto(conector)

# %%
faixas
# Out:
#   faixa_desconto  total_vendas  receita_total  lucro_total  volume_total  \
# 0   Sem desconto        625128    16886767.39   6755930.99       1875668
# 1          6–10%        124563     3023539.21   1209601.52        372814
# 2         11–15%        125405     2879166.34   1150410.62        375966
# 3         16–20%        124904     2696655.92   1078621.50        375141
#
#    margem_media_pct  receita_media_por_venda
# 0             40.01                    27.01
# 1             40.00                    24.27
# 2             39.97                    22.96
# 3             39.99                    21.59

# %%
correlacao
# Out:
# Correlação desconto × margem              -0.0017
# Margem média sem desconto                  40.01%
# Margem média com desconto                  39.99%
# Impacto médio do desconto na margem    -0.02 p.p.
# Total de vendas com desconto              374.872
# Total de vendas sem desconto              625.128
# Name: Impacto dos Descontos, dtype: str

# %% [markdown]
# ## Sazonalidade

# %% [markdown]
# Separa variação sazonal de tendência real, mais robusto que MoM para planejamento de médio prazo e definição de quando lançar produtos ou promover.

# %%
estatisticas = analysis.analisar_sazonalidade_yoy(conector)
estatisticas
# Out:
# (    mes  receita_2023  receita_2024  variacao_yoy_pct         padrao_sazonal
#  0     1    1095019.20    1084751.00             -0.94  Comportamento estável
#  1     2     968948.95    1010042.22              4.24  Sazonalidade positiva
#  2     3    1084656.09    1084560.82             -0.01  Comportamento estável
#  3     4    1038425.32    1043453.14              0.48  Comportamento estável
#  4     5    1083418.79    1078643.18             -0.44  Comportamento estável
#  5     6    1046045.02    1038214.24             -0.75  Comportamento estável
#  6     7    1083223.13    1085923.34              0.25  Comportamento estável
#  7     8    1086689.94    1082353.60             -0.40  Comportamento estável
#  8     9    1056935.75    1051414.03             -0.52  Comportamento estável
#  9    10    1071879.65    1075082.20              0.30  Comportamento estável
#  10   11    1039418.12    1039335.10             -0.01  Comportamento estável
#  11   12    1080446.31    1077249.72             -0.30  Comportamento estável,
#  Crescimento YoY médio                          0.16%
#  Melhor mês (maior crescimento YoY)     Mês 2 (4.24%)
#  Pior mês (menor crescimento YoY)      Mês 1 (-0.94%)
#  Meses com crescimento positivo                     4
#  Meses com crescimento negativo                     8
#  Desvio padrão das variações YoY            1.30 p.p.
#  Name: Sazonalidade Year-over-Year, dtype: str)

# %% [markdown]
# ## Visualizações

# %%
visualizations.visualizar_fidelidade(conector)
